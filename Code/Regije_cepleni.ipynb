# %%
import pandas as pd
import matplotlib.pyplot as plt

cepiva_po_regijah = pd.read_csv("csv/vaccination-by_region.csv")
cases_po_regijah = pd.read_csv("csv/region-cases.csv")
aktivnih = pd.read_csv("csv/region-active.csv")

aktivnih[['date','region.mb.active']]




x = aktivnih['date']
y = aktivnih['region.mb.active']
y2 = aktivnih['region.lj.active']
y3 = aktivnih['region.kk.active']
y4 = aktivnih['region.nm.active']
y5 = aktivnih['region.ms.active']
y6 = aktivnih['region.ng.active']
y7 = aktivnih['region.kp.active']



plt.figure(figsize=(25,10))
plt.plot(x,y, label = "Podravska")
plt.plot(x,y2, label = "Osrednjeslovenska")
plt.plot(x,y3, label = "Posavska")
plt.plot(x,y4, label = "Jugovzhodna Slovenija")
plt.plot(x,y5, label = "Pomurska")
plt.plot(x,y6, label = "Goriška")
plt.plot(x,y7, label = "Obalno-kraška")
plt.legend(loc = "upper left", prop = {'size': 25})



plt.xticks(range(0, len(x), len(x)//20), rotation=45)



plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
percantage = aktivnih
#percantage = pd.DataFrame(aktivnih, columns=['date'])
percantage['mb'] = percantage['region.mb.active'].div(328469)
percantage['lj'] = percantage['region.lj.active'].div(555948)
percantage['kk'] = percantage['region.kk.active'].div(75928)
percantage['nm'] = percantage['region.nm.active'].div(145923)
percantage['ms'] = percantage['region.ms.active'].div(114725)
percantage['ng'] = percantage['region.ng.active'].div(118525)
percantage['kp'] = percantage['region.kp.active'].div(118389)


x = percantage['date']
y = percantage['mb']
y2 = percantage['lj']
y3 = percantage['kk']
y4 = percantage['nm']
y5 = percantage['ms']
y6 = percantage['ng']
y7 = percantage['kp']



plt.figure(figsize=(25,10))
plt.plot(x,y, label = "Podravska")
plt.plot(x,y2, label = "Osrednjeslovenska")
plt.plot(x,y3, label = "Posavska")
plt.plot(x,y4, label = "Jugovzhodna Slovenija")
plt.plot(x,y5, label = "Pomurska")
plt.plot(x,y6, label = "Goriška")
plt.plot(x,y7, label = "Obalno-kraška")

plt.legend(loc = "upper left", prop = {'size': 25})
plt.xticks(range(0, len(x), len(x)//20), rotation=45)

plt.show()




#aktivnih['region.mb.active'].div(328469).dropna(0)

#x = aktivnih[['date','region.mb.active']]


#x = aktivnih[['date','region.mb.active']].fillna(0)
#x

# %%
from collections import defaultdict
percantage_cepiva = pd.DataFrame()


zadnji = cepiva_po_regijah.iloc[-1:]


zadnji

percantage_cepiva['Podravska'] = zadnji["vaccination.region.mb.1st.todate"].div(328469)
percantage_cepiva['Osrednjeslovenska'] = zadnji["vaccination.region.lj.1st.todate"].div(555948)
percantage_cepiva['Posavska'] = zadnji["vaccination.region.kk.1st.todate"].div(75928)
percantage_cepiva['Jugovzhodna Slovenija'] = zadnji["vaccination.region.nm.1st.todate"].div(145923)
percantage_cepiva['Pomurska'] = zadnji["vaccination.region.ms.1st.todate"].div(114725)
percantage_cepiva['Goriška'] = zadnji["vaccination.region.ng.1st.todate"].div(118525)
percantage_cepiva['Obalno Kraška'] = zadnji["vaccination.region.kp.1st.todate"].div(118389)

#RABIS ZADNJE VRSTICE IN NARDIS PROCENT NA REGIJO PRECEPLEJNOSTI....



slovar = defaultdict(float)

#plt.bar(*zip(*percantage_cepiva.items()))

regije = ["Podravska","Osrednjeslovenska","Posavska","Jugovzhodna Slovenija","Pomurska","Goriška","Obalno Kraška"]

for regija in regije:
   slovar[regija] = percantage_cepiva[regija]


seznam = percantage_cepiva.values.tolist()
seznam2 = []

for i in seznam[0]:
   seznam2.append(i)



plt.figure(figsize=(25,10))
plt.title("Odstotek populacije ceplejene vsaj 1-krat po regijah")
plt.xlabel("Regija")
plt.ylabel("Precepljenost")

plt.bar(regije,seznam2)


#for i,regija in enumerate(regije):
#   slovar[regija] = seznam[0[i]]


#slovar
#yikes = ["vaccination.region.mb.1st.todate","vaccination.region.lj.1st.todate","vaccination.region.kk.1st.todate",]

#percantage_cepiva["date"] = cepiva_po_regijah["date"]

#for regija in regije:
   # percantage_cepiva[regija] = 


#percantage_cepiva     


#percantage_cepiva['mb'] = percantage_cepiva['region.mb.active'].div(328469)
#percantage_cepiva['lj'] = percantage_cepiva['region.lj.active'].div(555948)
#percantage_cepiva['kk'] = percantage_cepiva['region.kk.active'].div(75928)
#percantage_cepiva['nm'] = percantage_cepiva['region.nm.active'].div(145923)
#percantage_cepiva['ms'] = percantage_cepiva['region.ms.active'].div(114725)
#percantage_cepiva['ng'] = percantage_cepiva['region.ng.active'].div(118525)
#percantage_cepiva['kp'] = percantage_cepiva['region.kp.active'].div(118389)
# Out:
# <BarContainer object of 7 artists>

# %%
list(cepiva_po_regijah)
# Out:
# ['date',
#  'vaccination.region.kp.1st',
#  'vaccination.region.kp.1st.todate',
#  'vaccination.region.kp.2nd',
#  'vaccination.region.kp.2nd.todate',
#  'vaccination.region.kp.3rd',
#  'vaccination.region.kp.3rd.todate',
#  'vaccination.region.ng.1st',
#  'vaccination.region.ng.1st.todate',
#  'vaccination.region.ng.2nd',
#  'vaccination.region.ng.2nd.todate',
#  'vaccination.region.ng.3rd',
#  'vaccination.region.ng.3rd.todate',
#  'vaccination.region.po.1st',
#  'vaccination.region.po.1st.todate',
#  'vaccination.region.po.2nd',
#  'vaccination.region.po.2nd.todate',
#  'vaccination.region.po.3rd',
#  'vaccination.region.po.3rd.todate',
#  'vaccination.region.kr.1st',
#  'vaccination.region.kr.1st.todate',
#  'vaccination.region.kr.2nd',
#  'vaccination.region.kr.2nd.todate',
#  'vaccination.region.kr.3rd',
#  'vaccination.region.kr.3rd.todate',
#  'vaccination.region.lj.1st',
#  'vaccination.region.lj.1st.todate',
#  'vaccination.region.lj.2nd',
#  'vaccination.region.lj.2nd.todate',
#  'vaccination.region.lj.3rd',
#  'vaccination.region.lj.3rd.todate',
#  'vaccination.region.nm.1st',
#  'vaccination.region.nm.1st.todate',
#  'vaccination.region.nm.2nd',
#  'vaccination.region.nm.2nd.todate',
#  'vaccination.region.nm.3rd',
#  'vaccination.region.nm.3rd.todate',
#  'vaccination.region.kk.1st',
#  'vaccination.region.kk.1st.todate',
#  'vaccination.region.kk.2nd',
#  'vaccination.region.kk.2nd.todate',
#  'vaccination.region.kk.3rd',
#  'vaccination.region.kk.3rd.todate',
#  'vaccination.region.za.1st',
#  'vaccination.region.za.1st.todate',
#  'vaccination.region.za.2nd',
#  'vaccination.region.za.2nd.todate',
#  'vaccination.region.za.3rd',
#  'vaccination.region.za.3rd.todate',
#  'vaccination.region.ce.1st',
#  'vaccination.region.ce.1st.todate',
#  'vaccination.region.ce.2nd',
#  'vaccination.region.ce.2nd.todate',
#  'vaccination.region.ce.3rd',
#  'vaccination.region.ce.3rd.todate',
#  'vaccination.region.sg.1st',
#  'vaccination.region.sg.1st.todate',
#  'vaccination.region.sg.2nd',
#  'vaccination.region.sg.2nd.todate',
#  'vaccination.region.sg.3rd',
#  'vaccination.region.sg.3rd.todate',
#  'vaccination.region.mb.1st',
#  'vaccination.region.mb.1st.todate',
#  'vaccination.region.mb.2nd',
#  'vaccination.region.mb.2nd.todate',
#  'vaccination.region.mb.3rd',
#  'vaccination.region.mb.3rd.todate',
#  'vaccination.region.ms.1st',
#  'vaccination.region.ms.1st.todate',
#  'vaccination.region.ms.2nd',
#  'vaccination.region.ms.2nd.todate',
#  'vaccination.region.ms.3rd',
#  'vaccination.region.ms.3rd.todate']

# %%
# Out:
#            date  vaccination.region.ng.ajdovščina.1st.todate  \
# 0    2021-05-03                                         4785
# 1    2021-05-04                                         4785
# 2    2021-05-05                                         4789
# 3    2021-05-06                                         5044
# 4    2021-05-07                                         5055
# ..          ...                                          ...
# 329  2022-03-28                                        12306
# 330  2022-03-29                                        12309
# 331  2022-03-30                                        12309
# 332  2022-03-31                                        12315
# 333  2022-04-01                                        12315
#
#      vaccination.region.ng.ajdovščina.2nd.todate  \
# 0                                           2571
# 1                                           2578
# 2                                           2596
# 3                                           2617
# 4                                           2823
# ..                                           ...
# 329                                        12015
# 330                                        12018
# 331                                        12018
# 332                                        12024
# 333                                        12024
#
#      vaccination.region.kp.ankaran.1st.todate  \
# 0                                         721
# 1                                         725
# 2                                         737
# 3                                         758
# 4                                         758
# ..                                        ...
# 329                                      1958
# 330                                      1959
# 331                                      1959
# 332                                      1959
# 333                                      1960
#
#      vaccination.region.kp.ankaran.2nd.todate  \
# 0                                         342
# 1                                         346
# 2                                         353
# 3                                         398
# 4                                         402
# ..                                        ...
# 329                                      1902
# 330                                      1903
# 331                                      1903
# 332                                      1904
# 333                                      1905
#
#      vaccination.region.ms.apače.1st.todate  \
# 0                                       520
# 1                                       528
# 2                                       559
# 3                                       636
# 4                                       637
# ..                                      ...
# 329                                    1906
# 330                                    1907
# 331                                    1907
# 332                                    1907
# 333                                    1907
#
#      vaccination.region.ms.apače.2nd.todate  \
# 0                                       222
# 1                                       263
# 2                                       266
# 3                                       266
# 4                                       266
# ..                                      ...
# 329                                    1836
# 330                                    1837
# 331                                    1837
# 332                                    1837
# 333                                    1837
#
#      vaccination.region.ms.beltinci.1st.todate  \
# 0                                         1528
# 1                                         1591
# 2                                         1598
# 3                                         1653
# 4                                         1677
# ..                                         ...
# 329                                       5020
# 330                                       5021
# 331                                       5021
# 332                                       5020
# 333                                       5024
#
#      vaccination.region.ms.beltinci.2nd.todate  \
# 0                                          694
# 1                                          703
# 2                                          718
# 3                                          770
# 4                                          770
# ..                                         ...
# 329                                       4875
# 330                                       4875
# 331                                       4881
# 332                                       4880
# 333                                       4884
#
#      vaccination.region.mb.benedikt.1st.todate  ...  \
# 0                                          396  ...
# 1                                          398  ...
# 2                                          409  ...
# 3                                          422  ...
# 4                                          423  ...
# ..                                         ...  ...
# 329                                       1356  ...
# 330                                       1350  ...
# 331                                       1350  ...
# 332                                       1352  ...
# 333                                       1354  ...
#
#      vaccination.region.kr.železniki.1st.todate  \
# 0                                          1231
# 1                                          1236
# 2                                          1239
# 3                                          1379
# 4                                          1387
# ..                                          ...
# 329                                        3923
# 330                                        3920
# 331                                        3920
# 332                                        3921
# 333                                        3922
#
#      vaccination.region.kr.železniki.2nd.todate  \
# 0                                           697
# 1                                           697
# 2                                           699
# 3                                           735
# 4                                           744
# ..                                          ...
# 329                                        3784
# 330                                        3781
# 331                                        3781
# 332                                        3784
# 333                                        3785
#
#      vaccination.region.mb.žetale.1st.todate  \
# 0                                        136
# 1                                        136
# 2                                        137
# 3                                        153
# 4                                        154
# ..                                       ...
# 329                                      658
# 330                                      658
# 331                                      658
# 332                                      657
# 333                                      657
#
#      vaccination.region.mb.žetale.2nd.todate  \
# 0                                         69
# 1                                         69
# 2                                         69
# 3                                         73
# 4                                         73
# ..                                       ...
# 329                                      634
# 330                                      634
# 331                                      634
# 332                                      633
# 333                                      633
#
#      vaccination.region.kr.žiri.1st.todate  \
# 0                                     1214
# 1                                     1214
# 2                                     1215
# 3                                     1254
# 4                                     1269
# ..                                     ...
# 329                                   3083
# 330                                   3083
# 331                                   3083
# 332                                   3081
# 333                                   3083
#
#      vaccination.region.kr.žiri.2nd.todate  \
# 0                                      621
# 1                                      621
# 2                                      624
# 3                                      661
# 4                                      714
# ..                                     ...
# 329                                   3021
# 330                                   3021
# 331                                   3021
# 332                                   3020
# 333                                   3022
#
#      vaccination.region.kr.žirovnica.1st.todate  \
# 0                                          1017
# 1                                          1050
# 2                                          1069
# 3                                          1114
# 4                                          1134
# ..                                          ...
# 329                                        2769
# 330                                        2774
# 331                                        2774
# 332                                        2774
# 333                                        2773
#
#      vaccination.region.kr.žirovnica.2nd.todate  \
# 0                                           541
# 1                                           542
# 2                                           543
# 3                                           557
# 4                                           566
# ..                                          ...
# 329                                        2711
# 330                                        2714
# 331                                        2714
# 332                                        2715
# 333                                        2714
#
#      vaccination.region.nm.žužemberk.1st.todate  \
# 0                                           749
# 1                                           753
# 2                                           781
# 3                                           842
# 4                                           853
# ..                                          ...
# 329                                        2722
# 330                                        2725
# 331                                        2725
# 332                                        2724
# 333                                        2725
#
#      vaccination.region.nm.žužemberk.2nd.todate
# 0                                           310
# 1                                           310
# 2                                           314
# 3                                           346
# 4                                           346
# ..                                          ...
# 329                                        2631
# 330                                        2634
# 331                                        2634
# 332                                        2633
# 333                                        2634
#
# [334 rows x 425 columns]

# %%
aktivnih.fillna(0)
ceplejni = pd.read_csv("csv/vaccination-administered.csv")
ceplejni = ceplejni.fillna(0)
aktivnih[['date','region.active']]

ceplejni["vsa_cepiva"] =  sum(ceplejni[attr] for attr in ["vaccination.administered.todate","vaccination.administered2nd.todate","vaccination.administered3rd.todate"])
ceplejni["vsa_cepiva"]




x = aktivnih['date']
y = aktivnih['region.active'].div(aktivnih['region.active'].max())
x1 = ceplejni['date']
y1 = ceplejni["vaccination.administered.todate"].div(ceplejni["vaccination.administered.todate"].max())

y2 = ceplejni["vaccination.administered2nd.todate"].div(ceplejni["vaccination.administered2nd.todate"].max())

y3 = ceplejni["vaccination.administered3rd.todate"].div(ceplejni["vaccination.administered3rd.todate"].max())






plt.figure(figsize=(25,10))
plt.plot(x,y, label = "aktivni")
plt.plot(x1,y1, label = "sštevilo cepljenih vsaj enkrat")
plt.plot(x1,y2, label = "sštevilo cepljenih drugič")
plt.plot(x1,y3, label = "sštevilo cepljenih tretjič")


plt.legend(loc = "upper left", prop = {'size': 25})
plt.xticks(range(0, len(x), len(x)//20), rotation=45)

# plt.show()


# ceplejni["vsa_cepiva"]


aktivnih['region.active']
# Out:
# 0          1
# 1          6
# 2         10
# 3         15
# 4         20
#        ...
# 753    38868
# 754    39090
# 755    39174
# 756    38840
# 757    38211
# Name: region.active, Length: 758, dtype: int64

# %%
x = aktivnih['date']
y = aktivnih['region.active']
x1 = ceplejni['date']
y1 = ceplejni["vaccination.administered.todate"]
y2 = ceplejni["vaccination.administered2nd.todate"]
y3 = ceplejni["vaccination.administered3rd.todate"]



plt.figure(figsize=(25,10))
plt.plot(x,y, label = "aktivni")
plt.plot(x1,y1, label = "sštevilo cepljenih vsaj enkrat")
plt.plot(x1,y2, label = "sštevilo cepljenih drugič")
plt.plot(x1,y3, label = "sštevilo cepljenih tretjič")


plt.legend(loc = "upper left", prop = {'size': 25})
plt.xticks(range(0, len(x), len(x)//20), rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x181cbe9ea60>,
#   <matplotlib.axis.XTick at 0x181cbe9e790>,
#   <matplotlib.axis.XTick at 0x181cbd82910>,
#   <matplotlib.axis.XTick at 0x181cbf45520>,
#   <matplotlib.axis.XTick at 0x181cbf45250>,
#   <matplotlib.axis.XTick at 0x181cc3a2490>,
#   <matplotlib.axis.XTick at 0x181cc3a2cd0>,
#   <matplotlib.axis.XTick at 0x181cbf61a00>,
#   <matplotlib.axis.XTick at 0x181cc3a2370>,
#   <matplotlib.axis.XTick at 0x181cbf45e20>,
#   <matplotlib.axis.XTick at 0x181cbf615e0>,
#   <matplotlib.axis.XTick at 0x181cbed0100>,
#   <matplotlib.axis.XTick at 0x181cbed0790>,
#   <matplotlib.axis.XTick at 0x181cbed0ee0>,
#   <matplotlib.axis.XTick at 0x181cbec8670>,
#   <matplotlib.axis.XTick at 0x181cbed06d0>,
#   <matplotlib.axis.XTick at 0x181cbf61160>,
#   <matplotlib.axis.XTick at 0x181cbec8100>,
#   <matplotlib.axis.XTick at 0x181cbeaa280>,
#   <matplotlib.axis.XTick at 0x181cbeaa9d0>,
#   <matplotlib.axis.XTick at 0x181cbec6160>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
