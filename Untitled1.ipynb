# %%
import pandas as pd
import matplotlib.pyplot as plt

cepiva_po_regijah = pd.read_csv("csv/vaccination-by_region.csv")
cases_po_regijah = pd.read_csv("csv/region-cases.csv")
aktivnih = pd.read_csv("csv/region-active.csv")

aktivnih[['date','region.mb.active']]




x = aktivnih['date']
y = aktivnih['region.mb.active']
y2 = aktivnih['region.lj.active']
y3 = aktivnih['region.kk.active']
y4 = aktivnih['region.nm.active']
y5 = aktivnih['region.ms.active']
y6 = aktivnih['region.ng.active']
y7 = aktivnih['region.kp.active']



plt.figure(figsize=(25,10))
plt.plot(x,y, label = "Podravska")
plt.plot(x,y2, label = "Osrednjeslovenska")
plt.plot(x,y3, label = "Posavska")
plt.plot(x,y4, label = "Jugovzhodna Slovenija")
plt.plot(x,y5, label = "Murska Sobota")
plt.plot(x,y6, label = "Goriška")
plt.plot(x,y7, label = "Obalno-kraška")
plt.legend(loc = "upper left", prop = {'size': 25})


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
percantage = aktivnih
#percantage = pd.DataFrame(aktivnih, columns=['date'])
percantage['mb'] = percantage['region.mb.active'].div(328469)
percantage['lj'] = percantage['region.lj.active'].div(555948)
percantage['kk'] = percantage['region.kk.active'].div(75928)
percantage['nm'] = percantage['region.nm.active'].div(145923)
percantage['ms'] = percantage['region.ms.active'].div(114725)
percantage['ng'] = percantage['region.ng.active'].div(118525)
percantage['kp'] = percantage['region.kp.active'].div(118389)


x = percantage['date']
y = percantage['mb']
y2 = percantage['lj']
y3 = percantage['kk']
y4 = percantage['nm']
y5 = percantage['ms']
y6 = percantage['ng']
y7 = percantage['kp']



plt.figure(figsize=(25,10))
plt.plot(x,y, label = "Podravska")
plt.plot(x,y2, label = "Osrednjeslovenska")
plt.plot(x,y3, label = "Posavska")
plt.plot(x,y4, label = "Jugovzhodna Slovenija")
plt.plot(x,y5, label = "Murska Sobota")
plt.plot(x,y6, label = "Goriška")
plt.plot(x,y7, label = "Obalno-kraška")

plt.legend(loc = "upper left", prop = {'size': 25})
plt.xticks(range(0, len(x), len(x)//20), rotation=45)

plt.show()




#aktivnih['region.mb.active'].div(328469).dropna(0)

#x = aktivnih[['date','region.mb.active']]


#x = aktivnih[['date','region.mb.active']].fillna(0)
#x

# %%
percantage_cepiva = pd.DataFrame()


zadnji = cepiva_po_regijah.iloc[-1:]

#RABIS ZADNJE VRSTICE IN NARDIS PROCENT NA REGIJO PRECEPLEJNOSTI....






#regije = ["mb","lj","kk","nm","ms","ng","kp"]
#yikes = ["vaccination.region.mb.1st.todate","vaccination.region.lj.1st.todate","vaccination.region.kk.1st.todate",]

#percantage_cepiva["date"] = cepiva_po_regijah["date"]

#for regija in regije:
   # percantage_cepiva[regija] = 


#percantage_cepiva     


#percantage_cepiva['mb'] = percantage_cepiva['region.mb.active'].div(328469)
#percantage_cepiva['lj'] = percantage_cepiva['region.lj.active'].div(555948)
#percantage_cepiva['kk'] = percantage_cepiva['region.kk.active'].div(75928)
#percantage_cepiva['nm'] = percantage_cepiva['region.nm.active'].div(145923)
#percantage_cepiva['ms'] = percantage_cepiva['region.ms.active'].div(114725)
#percantage_cepiva['ng'] = percantage_cepiva['region.ng.active'].div(118525)
#percantage_cepiva['kp'] = percantage_cepiva['region.kp.active'].div(118389)
# Out:
#            date  vaccination.region.kp.1st  vaccination.region.kp.1st.todate  \
# 459  2022-03-31                        NaN                             67299
#
#      vaccination.region.kp.2nd  vaccination.region.kp.2nd.todate  \
# 459                        NaN                           65047.0
#
#      vaccination.region.kp.3rd  vaccination.region.kp.3rd.todate  \
# 459                        1.0                           34173.0
#
#      vaccination.region.ng.1st  vaccination.region.ng.1st.todate  \
# 459                        NaN                             72339
#
#      vaccination.region.ng.2nd  ...  vaccination.region.mb.2nd  \
# 459                        NaN  ...                        NaN
#
#      vaccination.region.mb.2nd.todate  vaccination.region.mb.3rd  \
# 459                          179662.0                        4.0
#
#      vaccination.region.mb.3rd.todate  vaccination.region.ms.1st  \
# 459                           92702.0                        NaN
#
#      vaccination.region.ms.1st.todate  vaccination.region.ms.2nd  \
# 459                             69164                        NaN
#
#      vaccination.region.ms.2nd.todate  vaccination.region.ms.3rd  \
# 459                           67142.0                        3.0
#
#      vaccination.region.ms.3rd.todate
# 459                           36071.0
#
# [1 rows x 73 columns]

# %%
cepiva_po_regijah
# Out:
#            date  vaccination.region.kp.1st  vaccination.region.kp.1st.todate  \
# 0    2020-12-27                        NaN                               361
# 1    2020-12-28                       23.0                               384
# 2    2020-12-29                        NaN                               384
# 3    2020-12-30                       16.0                               400
# 4    2020-12-31                       15.0                               415
# ..          ...                        ...                               ...
# 455  2022-03-27                        NaN                             67295
# 456  2022-03-28                        NaN                             67295
# 457  2022-03-29                        NaN                             67295
# 458  2022-03-30                        4.0                             67299
# 459  2022-03-31                        NaN                             67299
#
#      vaccination.region.kp.2nd  vaccination.region.kp.2nd.todate  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# ..                         ...                               ...
# 455                        NaN                           65037.0
# 456                        1.0                           65038.0
# 457                        1.0                           65039.0
# 458                        8.0                           65047.0
# 459                        NaN                           65047.0
#
#      vaccination.region.kp.3rd  vaccination.region.kp.3rd.todate  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# ..                         ...                               ...
# 455                        NaN                           34139.0
# 456                        NaN                           34139.0
# 457                        3.0                           34142.0
# 458                       30.0                           34172.0
# 459                        1.0                           34173.0
#
#      vaccination.region.ng.1st  vaccination.region.ng.1st.todate  \
# 0                          NaN                               405
# 1                         28.0                               433
# 2                         21.0                               454
# 3                          6.0                               460
# 4                        315.0                               775
# ..                         ...                               ...
# 455                        NaN                             72338
# 456                        1.0                             72339
# 457                        NaN                             72339
# 458                        NaN                             72339
# 459                        NaN                             72339
#
#      vaccination.region.ng.2nd  ...  vaccination.region.mb.2nd  \
# 0                          NaN  ...                        NaN
# 1                          NaN  ...                        NaN
# 2                          NaN  ...                        NaN
# 3                          NaN  ...                        NaN
# 4                          NaN  ...                        NaN
# ..                         ...  ...                        ...
# 455                        NaN  ...                        NaN
# 456                        NaN  ...                        4.0
# 457                        NaN  ...                       11.0
# 458                        6.0  ...                       10.0
# 459                        NaN  ...                        NaN
#
#      vaccination.region.mb.2nd.todate  vaccination.region.mb.3rd  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# ..                                ...                        ...
# 455                          179637.0                        NaN
# 456                          179641.0                       87.0
# 457                          179652.0                       66.0
# 458                          179662.0                       85.0
# 459                          179662.0                        4.0
#
#      vaccination.region.mb.3rd.todate  vaccination.region.ms.1st  \
# 0                                 NaN                        NaN
# 1                                 NaN                      241.0
# 2                                 NaN                      146.0
# 3                                 NaN                       67.0
# 4                                 NaN                      161.0
# ..                                ...                        ...
# 455                           92460.0                        NaN
# 456                           92547.0                        1.0
# 457                           92613.0                        1.0
# 458                           92698.0                        NaN
# 459                           92702.0                        NaN
#
#      vaccination.region.ms.1st.todate  vaccination.region.ms.2nd  \
# 0                                 509                        NaN
# 1                                 750                        NaN
# 2                                 896                        NaN
# 3                                 963                        NaN
# 4                                1124                        NaN
# ..                                ...                        ...
# 455                             69162                        NaN
# 456                             69163                        1.0
# 457                             69164                        6.0
# 458                             69164                        2.0
# 459                             69164                        NaN
#
#      vaccination.region.ms.2nd.todate  vaccination.region.ms.3rd  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# ..                                ...                        ...
# 455                           67133.0                        NaN
# 456                           67134.0                       23.0
# 457                           67140.0                       35.0
# 458                           67142.0                       12.0
# 459                           67142.0                        3.0
#
#      vaccination.region.ms.3rd.todate
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 455                           35998.0
# 456                           36021.0
# 457                           36056.0
# 458                           36068.0
# 459                           36071.0
#
# [460 rows x 73 columns]
